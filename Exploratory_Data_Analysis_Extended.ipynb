# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt

from matplotlib import rcParams

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score as accuracy
from sklearn.metrics import recall_score as recall
from sklearn.metrics import precision_score as precision
from sklearn.metrics import f1_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

import os
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
import tensorflow as tf 
from sklearn.decomposition import PCA
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Masking, TimeDistributed

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
train_01 = pd.read_csv('/content/drive/My Drive/Booz_Allen/CMAPSSData/train_FD001.txt', delim_whitespace=True, header = None)
train_02 = pd.read_csv('/content/drive/My Drive/Booz_Allen/CMAPSSData/train_FD002.txt', delim_whitespace=True, header = None)
train_03 = pd.read_csv('/content/drive/My Drive/Booz_Allen/CMAPSSData/train_FD003.txt', delim_whitespace=True, header = None)
train_04 = pd.read_csv('/content/drive/My Drive/Booz_Allen/CMAPSSData/train_FD004.txt', delim_whitespace=True, header = None)

# %%
x = ['sensor_' + str(i) for i in range(1, 22)]
col_names = ['unit_number', 'time_cycles', 'op_setting_1', 'op_setting_2', 'op_setting_3'] + x
train_01.columns = col_names
train_02.columns = col_names
train_03.columns = col_names
train_04.columns = col_names

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[2], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[3], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[4], kind="kde")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[5], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[6], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[7], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[8], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[9], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[10], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[11], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[12], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[13], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[14], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[15], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[16], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[17], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[18], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[19], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[20], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[21], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[22], kind="kde")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[23], kind="kde")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[24], kind="kde")

# %%
for x in [train_01, train_02, train_03, train_04]:
  sns.displot(x, x=train_01.columns[25], kind="kde")

# %%
print("mean lifespan for train_01 is:", np.round(train_01.groupby(['unit_number']).count().mean()[0], 2))
print("mean lifespan for train_02 is:", np.round(train_02.groupby(['unit_number']).count().mean()[0], 2))
print("mean lifespan for train_03 is:", np.round(train_03.groupby(['unit_number']).count().mean()[0], 2))
print("mean lifespan for train_04 is:", np.round(train_04.groupby(['unit_number']).count().mean()[0], 2))
# Out:
# mean lifespan for train_01 is: 206.31
# mean lifespan for train_02 is: 206.77
# mean lifespan for train_03 is: 247.2
# mean lifespan for train_04 is: 245.98

# %%
df_corr = train_01.iloc[:, 5:].copy()
df_corr = df_corr.corr()
df_corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:1126: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:1127: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# ...

# %%
df_corr = train_02.iloc[:, 5:].copy()
df_corr = df_corr.corr()
df_corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
df_corr = train_03.iloc[:, 5:].copy()
df_corr = df_corr.corr()
df_corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:1126: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:1127: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# ...

# %%
df_corr = train_04.iloc[:, 5:].copy()
df_corr = df_corr.corr()
df_corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
rul_01 = pd.read_csv('/content/drive/My Drive/Booz_Allen/CMAPSSData/RUL_FD001.txt', delim_whitespace=True, header = None)
rul_02 = pd.read_csv('/content/drive/My Drive/Booz_Allen/CMAPSSData/RUL_FD002.txt', delim_whitespace=True, header = None)
rul_03 = pd.read_csv('/content/drive/My Drive/Booz_Allen/CMAPSSData/RUL_FD003.txt', delim_whitespace=True, header = None)
rul_04 = pd.read_csv('/content/drive/My Drive/Booz_Allen/CMAPSSData/RUL_FD004.txt', delim_whitespace=True, header = None)

# %%
rul_01["unit_number"] = range(1, len(rul_01) + 1)
rul_02["unit_number"] = range(1, len(rul_02) + 1)
rul_03["unit_number"] = range(1, len(rul_03) + 1)
rul_04["unit_number"] = range(1, len(rul_04) + 1)

# %%
for x in [rul_01, rul_02, rul_03, rul_04]:
  sns.displot(x, x=rul_01.columns[0], kind="kde")
